# %% [markdown]
# ![youtube%20cover%20%283%29.png](attachment:youtube%20cover%20%283%29.png)

# %% [markdown]
# # อย่าลืมกดซับให้ถึงล้านซับ

# %% [markdown]
# ช่วยเราถึงเป้าหมายโดยการชวนเพื่อนมากด subscribe youtube [Ultimate Python](https://bit.ly/ultimatepython-youtube)

# %% [markdown]
# # การทำงานบน Words

# %% [markdown]
# เป็นงานเอกสารที่หลายคนมีร่วมกัน ซึ่งการทำงานบน Words ด้วย Python มีหลักการอยู่ที่การระบุตำแหน่งที่ต้องการ และสั่งให้เกิดความเปลี่ยนแปลงที่ต้องการ ซึ่งในการเก็บข้อมูลของ Words มีอยู่ 2 ประเภทที่จะใช้งานเป็นหลัก และส่งผลต่อวิธีการระบุตำแหน่ง นั่นคือ 1) การเก็บข้อมูลในตาราง 2 การเก็บข้อมูลในบรรทัด
#
# เทคนิคที่แนะนำ คือ การเก็บข้อมูลที่ไม่เกี่ยวข้องกันไว้ในคนละตาราง และคนละช่องในตาราง เนื่องจากการเก็บข้อมูลในแต่ละบรรทัดอาจที่จัดเพื่อความสวยงามอาจมีการเก็บข้อมูลหลายอย่างอยู่ในบรรทัดเดียวกัน ทำให้จัดการกับข้อมูลเหล่านี้ได้ยาก แต่หากมีการเก็บในช่องตารางแยกกัน ข้อมูลเหล่านี้จะสามารถจัดการแยกกันได้อย่างมีประสิทธิภาพ แล้วจึงเข้าถึงข้อมูลรายบรรทัดในแต่ละช่องอีกที
#
# เมื่อระบุตำแหน่งข้อมูลได้แล้ว การทำการเปลี่ยนแปลงข้อมูลก็ประกอบไปด้วยอีกหลายส่วน ได้แก่ 1) ข้อมูลข้อความ 2) ข้อมูลอื่นๆ เช่น ฟอนท์, ขนาดตัวอักษร ซึ่งข้อมูลตัวอักษรสามารถแก้ไขได้ผ่านข้อมูลที่ถูกเก็บไว้ใน "text" แต่ข้อมูลฟอนท์จะถูกเก็บแยกไว้ในข้อมูล "run" ซึ่งเราจะได้เห็นการทำงานยิ่งขึ้นในคลิปสอน

# %% [markdown]
# # ตัวอย่างโปรแกรมลดงาน

# %% [markdown]
# ในตัวอย่างจะเป็นการสร้างโปรแกรมจาก 0 เพื่อใช้ดึงข้อมูลลูกค้าเพื่อมาออกเป็นใบเสร็จรับเงิน โดยมีเป้าหมายเพื่อให้โปรแกรมดึงรายละเอียดของลูกค้าทุกคนที่เรามีมาเพื่อออกใบเสร็จเป็นไฟล์ Words ที่ตั้งชื่อตามรหัสใบเสร็จใบนั้นๆ

# %% [markdown]
# ## ขั้นตอนการทำงานคร่าวๆ ของโปรแกรม

# %% [markdown]
# ดึงข้อมูลลูกค้า >> นำไปแก้ไขข้อความใน Words ที่เป็น template ของบิล >> เก็บตำแหน่งที่มีการเปลี่ยนแปลงข้อความมา >> นำตำแหน่งมาตั้งค่า font และ size >> ทำซ้ำให้ครบทุกข้อมูล >> บันทึกไฟล์ Words ใหม่เป็นชื่อรหัสใบเสร็จ

# %% [markdown]
# # ทดลองเขียนตามขั้นตอน

# %% [markdown]
# สำหรับคนที่อยากทดลองเขียนตามคลิปสอน [Ultimate Python](https://www.facebook.com/ultimatepython) ได้เรียบเรียงขั้นตอนแยกไว้ให้เรียนรู้ตามได้ง่ายตามขั้นตอนด้านล่าง สำหรับคนที่อยากเห็นโปรแกรมตัวเต็มสามารถดูได้จากด้านล่างของเอกสารนี้เลย

# %% [markdown]
# ## ติดตั้งเครื่องมือ

# %% [markdown]
# ## นำเข้าเครื่องมือ

# %% [markdown]
# ## เปิดไฟล์ Excel

# %% [markdown]
# ## ดึงข้อมูลที่ต้องการจาก Excel

# %% [markdown]
# ## เปิดไฟล์ Words

# %% [markdown]
# ## ดึงข้อมูลในตาราง

# %% [markdown]
# ## ดึงข้อมูลช่องในตาราง

# %% [markdown]
# ## ดึงข้อมูลบรรทัดในช่อง

# %% [markdown]
# ## บันทึกจุดที่เปลี่ยนแปลงข้อมูล

# %% [markdown]
# ## ทำการเปลี่ยนข้อมูล Font

# %% [markdown]
# ## บันทึกออกเป็นบิล

# %% [markdown]
# # โปรแกรมจากตัวอย่าง

# %% [markdown]
# โปรแกรมที่พัฒนาเสร็จแล้ว ทำการดึงไฟล์ RC.docx ที่เป็น template ของใบเสร็จ และข้อมูลลูกค้าจาก Sales.xlsx มาสร้างเป็นใบเสร็จบน Words โดยการระบุตำแหน่งการดึงข้อมูลจาก Excel และการระบุตำแหน่งที่ต้องการเปลี่ยนข้อความบน Words
#
# เมื่อทำความเข้าใจตามคลิป และเข้าใจการทำงานของโปรแกรมตัวนี้แล้ว สามารถปรับใช้กับงานที่คุณต้องทำบน Words แบบอัตโนมัติได้เลย!

# %% [markdown]
# ## ติดตั้งเครื่องมือ

# %%
pip install python-docx

# %%
pip install pandas

# %% [markdown]
# ## นำเข้าเครื่องมือที่ต้องการ

# %%
import docx
import pandas as pd
from docx import Document
from docx.shared import Pt

# %% [markdown]
# ## การดึงข้อมูล และสร้างตัวแปร

# %%
table = pd.read_excel('Sales.xlsx')
name = pd.read_excel('Sales.xlsx')['Name']
add_1 = table['Address 1']
add_2 = table['Address 1.1']
rc = table['Receipt ID']
date = table['Date']
product = table['Product']
unit = table['Unit']
unit_price = table['Unit Price']

# %% [markdown]
# ## โปรแกรมดึงข้อมูลลูกค้ามาออกบิล

# %%
doc = Document('RC.docx')
for i in range(len(table)):
    new_data = []
    doc.tables[1].cell(0,0).paragraphs[1].text = name[i]
    new_data.append(doc.tables[1].cell(0,0).paragraphs[1])
    doc.tables[1].cell(0,0).paragraphs[2].text = add_1[i]
    new_data.append(doc.tables[1].cell(0,0).paragraphs[2])
    doc.tables[1].cell(0,0).paragraphs[3].text = add_2[i]
    new_data.append(doc.tables[1].cell(0,0).paragraphs[3])
    doc.tables[1].cell(0,0).paragraphs[4].text = 'TAX ID: ' + str(table['Tax ID'][i])
    new_data.append(doc.tables[1].cell(0,0).paragraphs[4])
    doc.tables[1].cell(0,2).paragraphs[0].text = rc[i]
    new_data.append(doc.tables[1].cell(0,2).paragraphs[0])
    doc.tables[1].cell(0,2).paragraphs[1].text = str(date[i]).split()[0]
    new_data.append(doc.tables[1].cell(0,2).paragraphs[1])
    doc.tables[2].cell(1,0).paragraphs[0].text = product[i]
    new_data.append(doc.tables[2].cell(1,0).paragraphs[0])
    doc.tables[2].cell(1,1).paragraphs[0].text = str(unit[i])
    new_data.append(doc.tables[2].cell(1,1).paragraphs[0])
    doc.tables[2].cell(1,2).paragraphs[0].text = str(unit_price[i])
    new_data.append(doc.tables[2].cell(1,2).paragraphs[0])
    doc.tables[2].cell(1,3).paragraphs[0].text = str(unit_price[i]*unit[i])
    new_data.append(doc.tables[2].cell(1,3).paragraphs[0])
    doc.tables[3].cell(0,1).paragraphs[0].text = str(unit_price[i]*unit[i]) + ' THB'
    new_data.append(doc.tables[3].cell(0,1).paragraphs[0])
    doc.tables[3].cell(0,1).paragraphs[1].text = str(int(unit_price[i]*unit[i]*0.07)) + ' THB'
    new_data.append(doc.tables[3].cell(0,1).paragraphs[1])
    doc.tables[3].cell(0,1).paragraphs[2].text = str(int(unit_price[i]*unit[i]*1.07)) + ' THB'
    new_data.append(doc.tables[3].cell(0,1).paragraphs[2])
    for data in new_data:
        data.runs[0].font.name = 'Cordia New (Body CS)'
        data.runs[0].font.size = Pt(14)
    doc.save(rc[i]+'.docx')

# %% [markdown]
# # อยากมีเพื่อนแลกเปลี่ยนความรู้ Python

# %% [markdown]
# เข้าร่วมกลุ่ม [ลดงานด้วยPython](https://www.facebook.com/ultimatepython) โชว์ผลงาน หาไอเดียจากท่านอื่น หรือโพสสอบถามแลกเปลี่ยนได้เลย

# %% [markdown]
# # ให้เราช่วยคุณ

# %% [markdown]
# อยากเขียนเองเป็น อยากออกแบบระบบเองได้ แต่ไม่อยากลองผิดลองถูกเอง เรียนกับ "คอร์สลดงานด้วย Python" กับ Ultimate Python จาก 0 ได้เลย เรียนรู้เพิ่มเติมได้ที่ www.ultimatepython.co

# %% [markdown]
# ![%E0%B8%A5%E0%B8%94%E0%B8%87%E0%B8%B2%E0%B8%99%E0%B8%94%E0%B9%89%E0%B8%A7%E0%B8%A2%20Python%202021%20%282%29.png](attachment:%E0%B8%A5%E0%B8%94%E0%B8%87%E0%B8%B2%E0%B8%99%E0%B8%94%E0%B9%89%E0%B8%A7%E0%B8%A2%20Python%202021%20%282%29.png)
