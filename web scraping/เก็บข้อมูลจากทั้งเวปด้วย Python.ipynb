# %% [markdown]
# ![youtube%20cover%20%288%29.png](attachment:youtube%20cover%20%288%29.png)

# %% [markdown]
# # อย่าลืมกดซับให้ถึงล้านซับ

# %% [markdown]
# ช่วยเราถึงเป้าหมายโดยการชวนเพื่อนมากด subscribe youtube [Ultimate Python](https://bit.ly/ultimatepython-youtube)

# %% [markdown]
# # การทำงานกับข้อมูลเวปไซต์

# %% [markdown]
# ข้อมูลที่เราเห็นบนเวปไซต์เป็นผลลัพธ์ของโค้ด HTML ที่ไปดึงข้อมูลต่างๆ มาจัดเรียงให้สวยงามตามที่ตาเราเห็น โดย Browser จะทำความเข้าใจโค้ด HTML และเข้าไปดึงข้อความ รูป วิดีโอ หรือข้อมูลอื่นๆ ตามที่ HTML ตัวนั้นระบุจากอินเตอร์เน็ต และตีความออกมาเป็นหน้าเวปที่สวยงาม
#
# โค้ด HTML จะประกอบไปด้วยส่วนย่อยที่เรียกว่า Syntax ที่แบ่งส่วนการรับผิดชอบการแสดงผลของหน้าเวปแต่ละส่วนโดยมีลักษณะที่ซ้อนกันลงไปเป็นชั้นๆ เช่น Syntax ที่รับผิดชอบหน้าเวปทั้งหมด จะประกอบไปด้วย Syntax ที่รับผิดชอบหน้าเวปด้านบน และ Syntax ที่รับผิดชอบแถบโฆษณาด้านล่าง เป็นต้น
#
# หลักการสำคัญของการทำงานกับข้อมูลหน้าเวปในคลิปนี้ คือ การระบุ Syntax ที่เหมาะสมเพื่อการดึงข้อมูลที่เราต้องการ ให้สามารถดึงข้อมูลที่เกิดซ้ำๆ ได้อย่างมีประสิทธิภาพ โดยผ่านการระบุ ชื่อ และ Attribute
#
# สำหรับ Chrome เราสามารถดูโค้ด HTML ของเวปใดๆ ได้โดยการกด F12 (ในการเรียนรู้ในคลิปนี้แนะนำให้ติดตั้ง [Chrome](google.com/chrome/?brand=BNSD&gclid=Cj0KCQiA7NKBBhDBARIsAHbXCB4C87Cfd3clf7Sc6P5gNTcHbqcru_-xc_HKq-hqYPvyETvIR8oLeeAaAghVEALw_wcB&gclsrc=aw.ds))

# %% [markdown]
# # ตัวอย่างโปรแกรมลดงาน

# %% [markdown]
# ในตัวอย่างจะเป็นการสร้างโปรแกรมจาก 0 เพื่อดึงข้อมูลชื่อรถ และราคา ของรถทุกคัน จากเวปไซต์ [checkraka](https://www.checkraka.com/car/?quicksearch_order=update%2CDESC&page=1) แล้วนำข้อมูลมาเก็บเป็นไฟล์ Excel

# %% [markdown]
# ## ขั้นตอนการทำงานคร่าวๆ ของโปรแกรม

# %% [markdown]
# ดึงข้อมูล HTML เวป >> หา Syntax ที่เหมาะสม >> ดึงข้อมูลจาก Syntax >> บันทึกเป็นตาราง >> ทำซ้ำกับข้อมูลรถคันอื่นในหน้าปัจจุบัน >> ทำซ้ำกับหน้าอื่นของเวปไซต์ >> บันทึกข้อมูลทั้งหมดเป็นไฟล์ Excel

# %% [markdown]
# ## การใช้งาน

# %% [markdown]
# หากต้องการทดลองใช้งานให้กด / คลิกที่สัญลักษณ์ `In [ ]` สีน้ำเงินด้านซ้ายของหน้ากระดาษนี้ และกดปุ่ม `Run` ตามด้านล่าง ทำซ้ำจนครบทุกอัน โดยจะต้องทำตามลำดับจากอันด้านบนลงไปด้านล่างของกระดาษ

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# หากต้องการดูโฟลเดอร์ของไฟล์ Jupyter Notebook นี้ให้กดที่ File >> Open แล้วโฟลเดอร์ที่ไฟล์ Jupyter Notebook นี้อยู่จะถูกเปิดขึ้น

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # ทดลองเขียนตามขั้นตอน

# %% [markdown]
# สำหรับคนที่อยากทดลองเขียนตามคลิปสอน [Ultimate Python](https://www.facebook.com/ultimatepython) ได้เรียบเรียงขั้นตอนแยกไว้ให้เรียนรู้ตามได้ง่ายตามขั้นตอนด้านล่าง สำหรับคนที่อยากเห็นโปรแกรมตัวเต็มสามารถดูได้จากด้านล่างของเอกสารนี้เลย

# %% [markdown]
# ## ติดตั้งเครื่องมือ

# %% [markdown]
# ## นำเข้าเครื่องมือ

# %% [markdown]
# ## ดึงข้อมูล HTML

# %% [markdown]
# ## ดึงข้อมูลยี่ห้อรถ

# %% [markdown]
# ## ดึงข้อมูลราคารถ

# %% [markdown]
# ## ทำซ้ำกับรถทุกคนในหน้าเวป

# %% [markdown]
# ## บันทึกใส่ตาราง

# %% [markdown]
# ## เปลี่ยนเวปเป็นหน้าถัดไปจนครบ

# %% [markdown]
# ## สร้างคอลัมภ์ แถวใหม่

# %% [markdown]
# ## ส่งออกไฟล์เป็น Excel

# %% [markdown]
# # โปรแกรมจากตัวอย่าง

# %% [markdown]
# โปรแกรมที่พัฒนาเสร็จแล้ว ทำการดึงข้อมูลชื่อรถทุกรุ่น พร้อมราคา และบันทึกไว้ในไฟล์ All Cars.xlsx
#
# เมื่อทำความเข้าใจตามคลิป และเข้าใจการทำงานของโปรแกรมตัวนี้แล้ว สามารถปรับใช้เก็บข้อมูลจากหน้าเวปที่คุณต้องการได้เลย!

# %% [markdown]
# ## ติดตั้งเครื่องมือ

# %%
pip install bs4
# Out:
# ...
#      |████████████████████████████████| 115 kB 12.5 MB/s eta 0:00:01
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1272 sha256=9760bc0c1cff80a3b941bc4d565662bdd4eb1b4af342a414ac633289d5d02ae1
#   Stored in directory: /home/jovyan/.cache/pip/wheels/19/f5/6d/a97dd4f22376d4472d5f4c76c7646876052ff3166b3cf71050
# Successfully built bs4
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# ...
#      |████████████████████████████████| 242 kB 12.4 MB/s eta 0:00:01
# ...
#   Created wheel for et-xmlfile: filename=et_xmlfile-1.0.1-py3-none-any.whl size=8915 sha256=cd04d77fd7c833c534a94275a57f2cacb2babc68b2bb884a05676d659ac5fde0
#   Stored in directory: /home/jovyan/.cache/pip/wheels/ef/92/e0/956c00decf3091294b8800d9104f6169a1adacfaafd122ed42
# Successfully built et-xmlfile
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## นำเข้าเครื่องมือที่ต้องการ

# %%
import pandas as pd
import bs4
import requests
import openpyxl

# %% [markdown]
# ## เก็บข้อมูลจากทั้งเวปไซต์

# %%
page = 1
name_list = []
price_list = []
while page <= 110:
    data = requests.get('https://www.checkraka.com/car/?quicksearch_order=update%2CDESC&page=' + str(page))
    soup = bs4.BeautifulSoup(data.text)
    for c in soup.find_all('div',{'class':'content c158'}):
        name_list.append(c.find('div',{'class':'data'}).find('a').text)
        p = c.find('div',{'class':'price'}).text.split()[0].replace(',','')
        if p == 'call':
            price_list.append(p)
        else:
            price_list.append(int(p))
    print('Complete page number: ',page)
    page += 1
table = pd.DataFrame([name_list,price_list]).transpose()
table.columns = ['name','price']
table.set_index('name')
table.to_excel('All Cars.xlsx',engine='openpyxl')
# Out:
# Complete page number:  1
# Complete page number:  2
# Complete page number:  3
# Complete page number:  4
# Complete page number:  5
# Complete page number:  6
# Complete page number:  7
# Complete page number:  8
# Complete page number:  9
# Complete page number:  10
# Complete page number:  11
# Complete page number:  12
# Complete page number:  13
# Complete page number:  14
# Complete page number:  15
# Complete page number:  16
# Complete page number:  17
# Complete page number:  18
# Complete page number:  19
# Complete page number:  20
# Complete page number:  21
# Complete page number:  22
# Complete page number:  23
# Complete page number:  24
# Complete page number:  25
# Complete page number:  26
# Complete page number:  27
# Complete page number:  28
# Complete page number:  29
# Complete page number:  30
# Complete page number:  31
# Complete page number:  32
# Complete page number:  33
# Complete page number:  34
# Complete page number:  35
# Complete page number:  36
# ...

# %% [markdown]
# # อยากมีเพื่อนแลกเปลี่ยนความรู้ Python

# %% [markdown]
# เข้าร่วมกลุ่ม [ลดงานด้วยPython](https://www.facebook.com/ultimatepython) โชว์ผลงาน หาไอเดียจากท่านอื่น หรือโพสสอบถามแลกเปลี่ยนได้เลย

# %% [markdown]
# # ให้เราช่วยคุณ

# %% [markdown]
# อยากเขียนเองเป็น อยากออกแบบระบบเองได้ แต่ไม่อยากลองผิดลองถูกเอง เรียนกับ "คอร์สลดงานด้วย Python" กับ Ultimate Python จาก 0 ได้เลย เรียนรู้เพิ่มเติมได้ที่ www.ultimatepython.co

# %% [markdown]
# ![%E0%B8%A5%E0%B8%94%E0%B8%87%E0%B8%B2%E0%B8%99%E0%B8%94%E0%B9%89%E0%B8%A7%E0%B8%A2%20Python%202021%20%282%29.png](attachment:%E0%B8%A5%E0%B8%94%E0%B8%87%E0%B8%B2%E0%B8%99%E0%B8%94%E0%B9%89%E0%B8%A7%E0%B8%A2%20Python%202021%20%282%29.png)
